# %%
import pandas as pd 
allDataA = pd.read_csv('AllData_PreEDM_Virgin_RowColIDs.csv')
allDataA
# Out:
#       Row  B3_DATUM_B_LOC  B3_REF_OD  C1_LOC_INSIDE_PLN  C4_LOC_TOP_PLN  \
# 0     Aa1          0.4176     0.4481             0.0545          0.2661
# 1     Aa3          0.4178     0.4483             0.0540          0.2663
# 2     Aa5          0.4176     0.4485             0.0539          0.2658
# 3     Aa7          0.4180     0.4480             0.0537          0.2655
# 4     Aa9          0.4176     0.4483             0.0531          0.2652
# ..    ...             ...        ...                ...             ...
# 771   Kk7          0.4173     0.4477             0.0535          0.2657
# 772   Kk8          0.4169     0.4483             0.0533          0.2655
# 773   Kk9          0.4168     0.4494             0.0520          0.2649
# 774  Kk10          0.4166     0.4487             0.0514          0.2649
# 775  Kk11          0.4161     0.4481             0.0509          0.2644
#
#      B3_THICK1_WALL  B3_THICK2_WALL  B3_THICK3_WALL  B3_THICK4_WALL   Layout  \
# 0            0.0158          0.0152          0.0153          0.0144      6X6
# 1            0.0169          0.0154          0.0149          0.0151      6X6
# 2            0.0155          0.0156          0.0144          0.0157      6X6
# 3            0.0149          0.0149          0.0149          0.0152      6X6
# 4            0.0184          0.0158          0.0159          0.0160      6X6
# ..              ...             ...             ...             ...      ...
# 771          0.0158          0.0156          0.0165          0.0169  11X11TA
# 772          0.0164          0.0157          0.0154          0.0156  11X11TA
# 773          0.0175          0.0165          0.0160          0.0158  11X11TA
# 774          0.0168          0.0161          0.0165          0.0170  11X11TA
# 775          0.0163          0.0160          0.0156          0.0157  11X11TA
#
#      BuildDate  Powder MeasureSeq  Nonconformity  RowID  ColID PlateID
# 0     8/5/2019  Virgin     PreEDM          False      1      1       A
# 1     8/5/2019  Virgin     PreEDM          False      1      3       A
# 2     8/5/2019  Virgin     PreEDM          False      1      5       A
# 3     8/5/2019  Virgin     PreEDM          False      1      7       A
# 4     8/5/2019  Virgin     PreEDM          False      1      9       A
# ..         ...     ...        ...            ...    ...    ...     ...
# 771  8/21/2019  Virgin     PreEDM          False     11      7       K
# 772  8/21/2019  Virgin     PreEDM          False     11      8       K
# 773  8/21/2019  Virgin     PreEDM          False     11      9       K
# 774  8/21/2019  Virgin     PreEDM          False     11     10       K
# 775  8/21/2019  Virgin     PreEDM          False     11     11       K
#
# [776 rows x 17 columns]

# %%
import pandas as pd 
allDataB = pd.read_csv('AllData_PreEDM_Recycled_RowColIDs.csv')
allDataB
# Out:
#       Row  B3_DATUM_B_LOC  B3_REF_OD  C1_LOC_INSIDE_PLN  C4_LOC_TOP_PLN  \
# 0     La1          0.4171     0.4476             0.0539          0.2659
# 1     La2          0.4164     0.4478             0.0534          0.2662
# 2     La3          0.4173     0.4479             0.0541          0.2668
# 3     La4          0.4172     0.4485             0.0531          0.2663
# 4     La5          0.4175     0.4487             0.0541          0.2663
# ..    ...             ...        ...                ...             ...
# 779   Rk7          0.4143     0.4509             0.0541          0.2672
# 780   Rk8          0.4146     0.4512             0.0549          0.2669
# 781   Rk9          0.4160     0.4515             0.0540          0.2660
# 782  Rk10          0.4157     0.4510             0.0536          0.2653
# 783  Rk11          0.4147     0.4509             0.0533          0.2653
#
#      B3_THICK1_WALL  B3_THICK2_WALL  B3_THICK3_WALL  B3_THICK4_WALL   Layout  \
# 0            0.0158          0.0160          0.0149          0.0164  11X11TA
# 1            0.0168          0.0167          0.0152          0.0141  11X11TA
# 2            0.0151          0.0163          0.0155          0.0151  11X11TA
# 3            0.0155          0.0157          0.0183          0.0147  11X11TA
# 4            0.0153          0.0153          0.0156          0.0153  11X11TA
# ..              ...             ...             ...             ...      ...
# 779          0.0172          0.0190          0.0167          0.0187  11X11TA
# 780          0.0158          0.0181          0.0161          0.0189  11X11TA
# 781          0.0160          0.0184          0.0153          0.0203  11X11TA
# 782          0.0150          0.0197          0.0159          0.0196  11X11TA
# 783          0.0164          0.0206          0.0167          0.0202  11X11TA
#
#      BuildDate    Powder MeasureSeq  Nonconformity  RowID  ColID PlateID
# 0    8/22/2019  Recycled     PreEDM          False      1      1       L
# 1    8/22/2019  Recycled     PreEDM          False      1      2       L
# 2    8/22/2019  Recycled     PreEDM          False      1      3       L
# 3    8/22/2019  Recycled     PreEDM          False      1      4       L
# 4    8/22/2019  Recycled     PreEDM          False      1      5       L
# ..         ...       ...        ...            ...    ...    ...     ...
# 779  8/30/2019  Recycled     PreEDM          False     11      7       R
# 780  8/30/2019  Recycled     PreEDM          False     11      8       R
# 781  8/30/2019  Recycled     PreEDM          False     11      9       R
# 782  8/30/2019  Recycled     PreEDM          False     11     10       R
# 783  8/30/2019  Recycled     PreEDM          False     11     11       R
#
# [784 rows x 17 columns]

# %%
df = pd.concat([allDataA, allDataB])
df
# Out:
#       Row  B3_DATUM_B_LOC  B3_REF_OD  C1_LOC_INSIDE_PLN  C4_LOC_TOP_PLN  \
# 0     Aa1          0.4176     0.4481             0.0545          0.2661
# 1     Aa3          0.4178     0.4483             0.0540          0.2663
# 2     Aa5          0.4176     0.4485             0.0539          0.2658
# 3     Aa7          0.4180     0.4480             0.0537          0.2655
# 4     Aa9          0.4176     0.4483             0.0531          0.2652
# ..    ...             ...        ...                ...             ...
# 779   Rk7          0.4143     0.4509             0.0541          0.2672
# 780   Rk8          0.4146     0.4512             0.0549          0.2669
# 781   Rk9          0.4160     0.4515             0.0540          0.2660
# 782  Rk10          0.4157     0.4510             0.0536          0.2653
# 783  Rk11          0.4147     0.4509             0.0533          0.2653
#
#      B3_THICK1_WALL  B3_THICK2_WALL  B3_THICK3_WALL  B3_THICK4_WALL   Layout  \
# 0            0.0158          0.0152          0.0153          0.0144      6X6
# 1            0.0169          0.0154          0.0149          0.0151      6X6
# 2            0.0155          0.0156          0.0144          0.0157      6X6
# 3            0.0149          0.0149          0.0149          0.0152      6X6
# 4            0.0184          0.0158          0.0159          0.0160      6X6
# ..              ...             ...             ...             ...      ...
# 779          0.0172          0.0190          0.0167          0.0187  11X11TA
# 780          0.0158          0.0181          0.0161          0.0189  11X11TA
# 781          0.0160          0.0184          0.0153          0.0203  11X11TA
# 782          0.0150          0.0197          0.0159          0.0196  11X11TA
# 783          0.0164          0.0206          0.0167          0.0202  11X11TA
#
#      BuildDate    Powder MeasureSeq  Nonconformity  RowID  ColID PlateID
# 0     8/5/2019    Virgin     PreEDM          False      1      1       A
# 1     8/5/2019    Virgin     PreEDM          False      1      3       A
# 2     8/5/2019    Virgin     PreEDM          False      1      5       A
# 3     8/5/2019    Virgin     PreEDM          False      1      7       A
# 4     8/5/2019    Virgin     PreEDM          False      1      9       A
# ..         ...       ...        ...            ...    ...    ...     ...
# 779  8/30/2019  Recycled     PreEDM          False     11      7       R
# 780  8/30/2019  Recycled     PreEDM          False     11      8       R
# 781  8/30/2019  Recycled     PreEDM          False     11      9       R
# 782  8/30/2019  Recycled     PreEDM          False     11     10       R
# 783  8/30/2019  Recycled     PreEDM          False     11     11       R
#
# [1560 rows x 17 columns]

# %%
df['Location'] = df['Row'].str.replace(r'[A-Z]', '', regex=True)
df
# Out:
#       Row  B3_DATUM_B_LOC  B3_REF_OD  C1_LOC_INSIDE_PLN  C4_LOC_TOP_PLN  \
# 0     Aa1          0.4176     0.4481             0.0545          0.2661
# 1     Aa3          0.4178     0.4483             0.0540          0.2663
# 2     Aa5          0.4176     0.4485             0.0539          0.2658
# 3     Aa7          0.4180     0.4480             0.0537          0.2655
# 4     Aa9          0.4176     0.4483             0.0531          0.2652
# ..    ...             ...        ...                ...             ...
# 779   Rk7          0.4143     0.4509             0.0541          0.2672
# 780   Rk8          0.4146     0.4512             0.0549          0.2669
# 781   Rk9          0.4160     0.4515             0.0540          0.2660
# 782  Rk10          0.4157     0.4510             0.0536          0.2653
# 783  Rk11          0.4147     0.4509             0.0533          0.2653
#
#      B3_THICK1_WALL  B3_THICK2_WALL  B3_THICK3_WALL  B3_THICK4_WALL   Layout  \
# 0            0.0158          0.0152          0.0153          0.0144      6X6
# 1            0.0169          0.0154          0.0149          0.0151      6X6
# 2            0.0155          0.0156          0.0144          0.0157      6X6
# 3            0.0149          0.0149          0.0149          0.0152      6X6
# 4            0.0184          0.0158          0.0159          0.0160      6X6
# ..              ...             ...             ...             ...      ...
# 779          0.0172          0.0190          0.0167          0.0187  11X11TA
# 780          0.0158          0.0181          0.0161          0.0189  11X11TA
# 781          0.0160          0.0184          0.0153          0.0203  11X11TA
# 782          0.0150          0.0197          0.0159          0.0196  11X11TA
# 783          0.0164          0.0206          0.0167          0.0202  11X11TA
#
#      BuildDate    Powder MeasureSeq  Nonconformity  RowID  ColID PlateID  \
# 0     8/5/2019    Virgin     PreEDM          False      1      1       A
# 1     8/5/2019    Virgin     PreEDM          False      1      3       A
# 2     8/5/2019    Virgin     PreEDM          False      1      5       A
# 3     8/5/2019    Virgin     PreEDM          False      1      7       A
# 4     8/5/2019    Virgin     PreEDM          False      1      9       A
# ..         ...       ...        ...            ...    ...    ...     ...
# 779  8/30/2019  Recycled     PreEDM          False     11      7       R
# 780  8/30/2019  Recycled     PreEDM          False     11      8       R
# 781  8/30/2019  Recycled     PreEDM          False     11      9       R
# 782  8/30/2019  Recycled     PreEDM          False     11     10       R
# 783  8/30/2019  Recycled     PreEDM          False     11     11       R
#
#     Location
# 0         a1
# 1         a3
# 2         a5
# 3         a7
# 4         a9
# ..       ...
# 779       k7
# 780       k8
# 781       k9
# 782      k10
# 783      k11
#
# [1560 rows x 18 columns]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# machine learning imports
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.dummy import DummyRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score

# preprocessing imports
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

# %%
X = df[['Layout', 'Powder', 'Location', 'PlateID']]
X
# Out:
#       Layout    Powder Location PlateID
# 0        6X6    Virgin       a1       A
# 1        6X6    Virgin       a3       A
# 2        6X6    Virgin       a5       A
# 3        6X6    Virgin       a7       A
# 4        6X6    Virgin       a9       A
# ..       ...       ...      ...     ...
# 779  11X11TA  Recycled       k7       R
# 780  11X11TA  Recycled       k8       R
# 781  11X11TA  Recycled       k9       R
# 782  11X11TA  Recycled      k10       R
# 783  11X11TA  Recycled      k11       R
#
# [1560 rows x 4 columns]

# %%
y = df['Nonconformity']
y
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 779    False
# 780    False
# 781    False
# 782    False
# 783    False
# Name: Nonconformity, Length: 1560, dtype: bool

# %%
# splitting the train data into train and validation sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# preprocessing the data (scaling, imputing, encoding)
categorical_features = ['Layout', 'Powder', 'Location', 'PlateID']

cat_pipe = make_pipeline(
    SimpleImputer(strategy="most_frequent"),
    OneHotEncoder(handle_unknown="ignore", dtype=np.int8)
)

preprocessor = make_column_transformer(
    (cat_pipe, categorical_features),
    remainder="drop"
)

# %%
Cs = np.logspace(-3, 2, 12)  # 0.001 → 100
rows = []

for C in Cs:
    pipe = Pipeline(steps=[
        ("pre", preprocessor),
        ("clf", LogisticRegression(
            penalty="l1",
            solver="saga",        # must use saga for L1
            C=C,
            #max_iter=5000,
            class_weight="balanced"  # helpful if classes are imbalanced
        ))
    ])
    pipe.fit(X_train, y_train)
    y_prob = pipe.predict_proba(X_test)[:, 1]
    y_pred = (y_prob >= 0.5).astype(int)

    rows.append({
        "C": C,
        "roc_auc": roc_auc_score(y_test, y_prob),
        "f1": f1_score(y_test, y_pred),
        "accuracy": accuracy_score(y_test, y_pred),
        # sparsity: how many nonzero coefficients after one-hot
        "nnz": (pipe.named_steps["clf"].coef_ != 0).sum()
    })

results = pd.DataFrame(rows).sort_values(["roc_auc","f1"], ascending=False)
print(results)

# best C (by ROC AUC here)
best_C = results.iloc[0]["C"]
print("Best C by AUC:", best_C)
# Out:
# /Users/brisajasso/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brisajasso/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brisajasso/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brisajasso/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brisajasso/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brisajasso/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brisajasso/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brisajasso/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brisajasso/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
#              C   roc_auc        f1  accuracy  nnz
# 10   35.111917  0.702516  0.000000  0.971154   30
# 8     4.328761  0.691153  0.000000  0.971154   26
# 9    12.328467  0.681412  0.000000  0.974359   26
# 5     0.187382  0.613231  0.021505  0.708333   52
# 11  100.000000  0.569805  0.000000  0.971154  111
# 7     1.519911  0.561688  0.000000  0.964744   24
# 6     0.533670  0.554789  0.000000  0.958333   22
# 3     0.023101  0.546266  0.021978  0.429487   24
# 0     0.001000  0.500000  0.025316  0.012821    0
# 1     0.002848  0.500000  0.025316  0.012821    0
# 4     0.065793  0.394481  0.000000  0.692308   28
# 2     0.008111  0.265422  0.000000  0.987179   11
# Best C by AUC: 35.11191734215127
# /Users/brisajasso/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
best_pipe = Pipeline(steps=[
    ("pre", preprocessor),
    ("clf", LogisticRegression(
        penalty="l1", solver="saga", C=best_C,
        class_weight="balanced", max_iter=5000
    ))
])
best_pipe.fit(X_train, y_train)

# 2) Get per-row probabilities on the TEST set (holdout)
y_prob_test = best_pipe.predict_proba(X_test)[:, 1]
y_prob_test

res = X_test.copy()
res["Scrap_Prob"] = y_prob_test
res["Actual"] = y_test.values 
res[res['Actual']==True]
results[['C','nnz']]
# Out:
# /Users/brisajasso/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
#              C  nnz
# 10   35.111917   30
# 8     4.328761   26
# 9    12.328467   26
# 5     0.187382   52
# 11  100.000000  111
# 7     1.519911   24
# 6     0.533670   22
# 3     0.023101   24
# 0     0.001000    0
# 1     0.002848    0
# 4     0.065793   28
# 2     0.008111   11

# %%
# 1) Refit at best_C
best_pipe = Pipeline(steps=[
    ("pre", preprocessor),
    ("clf", LogisticRegression(
        penalty="l1", solver="saga",
        C=float(best_C),
        max_iter=20000, tol=1e-3,
        class_weight="balanced",
        random_state=42
    ))
])
best_pipe.fit(X_train, y_train)

# 2) Get feature names after preprocessing (from the FITTED ColumnTransformer)
ct = best_pipe.named_steps["pre"]               # the fitted ColumnTransformer
feature_names = ct.get_feature_names_out()      # works across transformers (incl. OHE)

# 3) Get coefficients from the fitted logistic regression
coefs = best_pipe.named_steps["clf"].coef_.ravel()

# 4) Build coef table and show strongest signals
import pandas as pd
coef_df = pd.DataFrame({"feature": feature_names, "coef": coefs})
coef_df_nonzero = coef_df[coef_df["coef"] != 0]

print("Top + predictors (push toward Nonconformity=1):")
print(coef_df_nonzero.sort_values("coef", ascending=False).head(10))

print("\nTop − predictors (push toward Nonconformity=0):")
print(coef_df_nonzero.sort_values("coef", ascending=True).head(10))
# Out:
# Top + predictors (push toward Nonconformity=1):
#                     feature        coef
# 112   pipeline__Location_k5  357.201573
# 20    pipeline__Location_a6  329.311214
# 104   pipeline__Location_i8  324.949595
# 19    pipeline__Location_a5  283.349489
# 15   pipeline__Location_a11  276.223790
# 114   pipeline__Location_k7  271.533789
# 86   pipeline__Location_h11  270.605153
# 123     pipeline__PlateID_G  188.848184
# 124     pipeline__PlateID_H  118.141245
# 126     pipeline__PlateID_J  105.317985
#
# Top − predictors (push toward Nonconformity=0):
#                      feature        coef
# 132      pipeline__PlateID_P -166.143496
# 131      pipeline__PlateID_O -158.560415
# 128      pipeline__PlateID_L -146.390741
# 4    pipeline__Powder_Virgin -120.220520
# 118      pipeline__PlateID_B  -22.064416
# 122      pipeline__PlateID_F  -21.013352
# 119      pipeline__PlateID_C  -20.035667
# 127      pipeline__PlateID_K  -16.240036
# 2     pipeline__Layout_6X6TA   -8.267729
# 120      pipeline__PlateID_D   -4.316356
# /Users/brisajasso/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
